# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding, GRU, SimpleRNN
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras import regularizers
from keras.layers import LeakyReLU
from keras.callbacks import EarlyStopping
from keras.callbacks import Callback
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization
from keras.initializers import he_normal, glorot_normal
from keras.optimizers import Adam

# %matplotlib inline

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# ## Load Dataset

# %%
pd.set_option('display.max_colwidth', None)

df_tweets = pd.read_csv('./tweet.csv')
df_tweets.head()
# Out:
#    Unnamed: 0 sentimen  \
# 0           0  negatif
# 1           1   netral
# 2           2   netral
# 3           3  positif
# 4           4  negatif
#
#                                                                                                                                                                                                                                                   tweet
# 0                                                   Kata @prabowo Indonesia tidak dihargai bangsa asing!   Berita ini ðŸ‘‡ pasti hoax buatan penguasa, ya kan @rockygerung?ðŸ˜œ https://twitter.com/mediaindonesia/status/1117575436337160192?s=21Â â€¦
# 1                                                                                                                                                         Batuan Langka, Tasbih Jokowi Hadiah dari Habib Luthfi Seharga Mercy?  http://dlvr.it/R2pvZVÂ
# 2                                                                                                                        Di era Jokowi, ekonomi Indonesia semakin baik. #01IndonesiaMaju #JokowiLagi #JokowiMenangTotalDebat pic.twitter.com/W2ythnxsTp
# 3                                                                                                                      Bagi Sumatera Selatan, Asian Games berdampak pd ekonomi langsung diprediksi mencapai 18,5 triliun. Indonesia maju, Jokowi hebat!
# 4  Negara kita ngutang buat bngun infrastruktur yang udah dipake masyarakat, terus masyarakatnya ngeluh karena negara ngutang, setiap negara itu pasti ngutang,  utang bisa dibayar kalo negara dapet penghasilan. Penghasilan negara itu ya dari pajak

# %%
#Drop kolom yang tidak diperlukan

df_tweets = df_tweets.drop(columns=['Unnamed: 0'])
df_tweets.head()
# Out:
#   sentimen  \
# 0  negatif
# 1   netral
# 2   netral
# 3  positif
# 4  negatif
#
#                                                                                                                                                                                                                                                   tweet
# 0                                                   Kata @prabowo Indonesia tidak dihargai bangsa asing!   Berita ini ðŸ‘‡ pasti hoax buatan penguasa, ya kan @rockygerung?ðŸ˜œ https://twitter.com/mediaindonesia/status/1117575436337160192?s=21Â â€¦
# 1                                                                                                                                                         Batuan Langka, Tasbih Jokowi Hadiah dari Habib Luthfi Seharga Mercy?  http://dlvr.it/R2pvZVÂ
# 2                                                                                                                        Di era Jokowi, ekonomi Indonesia semakin baik. #01IndonesiaMaju #JokowiLagi #JokowiMenangTotalDebat pic.twitter.com/W2ythnxsTp
# 3                                                                                                                      Bagi Sumatera Selatan, Asian Games berdampak pd ekonomi langsung diprediksi mencapai 18,5 triliun. Indonesia maju, Jokowi hebat!
# 4  Negara kita ngutang buat bngun infrastruktur yang udah dipake masyarakat, terus masyarakatnya ngeluh karena negara ngutang, setiap negara itu pasti ngutang,  utang bisa dibayar kalo negara dapet penghasilan. Penghasilan negara itu ya dari pajak

# %% [markdown]
# ## EDA

# %%
df_tweets
# Out:
#      sentimen  \
# 0     negatif
# 1      netral
# 2      netral
# 3     positif
# 4     negatif
# ...       ...
# 1810   netral
# 1811   netral
# 1812   netral
# 1813   netral
# 1814   netral
#
#                                                                                                                                                                                                                                                      tweet
# 0                                                      Kata @prabowo Indonesia tidak dihargai bangsa asing!   Berita ini ðŸ‘‡ pasti hoax buatan penguasa, ya kan @rockygerung?ðŸ˜œ https://twitter.com/mediaindonesia/status/1117575436337160192?s=21Â â€¦
# 1                                                                                                                                                            Batuan Langka, Tasbih Jokowi Hadiah dari Habib Luthfi Seharga Mercy?  http://dlvr.it/R2pvZVÂ
# 2                                                                                                                           Di era Jokowi, ekonomi Indonesia semakin baik. #01IndonesiaMaju #JokowiLagi #JokowiMenangTotalDebat pic.twitter.com/W2ythnxsTp
# 3                                                                                                                         Bagi Sumatera Selatan, Asian Games berdampak pd ekonomi langsung diprediksi mencapai 18,5 triliun. Indonesia maju, Jokowi hebat!
# 4     Negara kita ngutang buat bngun infrastruktur yang udah dipake masyarakat, terus masyarakatnya ngeluh karena negara ngutang, setiap negara itu pasti ngutang,  utang bisa dibayar kalo negara dapet penghasilan. Penghasilan negara itu ya dari pajak
# ...                                                                                                                                                                                                                                                    ...
# 1810                                                                                                                                                   Negarawan sejati sll bangga dan mengedepankan harga diri bangsanya yg berdaulat  #2019GantiPresiden
# 1811                                                                                                                                                                      1. HRS ceramah di Damai Indonesiaku 2. Perekonomian makin membaik.  #PutihkanGBK
# 1812                                                                                                  Mari bangun bangsa dgn mendukung perekonomian negara bersama Pak Jokowi. Ayo kerja!  https://twitter.com/KaskusLoker/status/1111643312241295363Â â€¦
# 1813                                                                                                                             Bantu majukan perekonomian bangsa bersama Pak Jokowi, yuk!  https://twitter.com/BKNSquare/status/1113655944955588610Â â€¦
# 1814                                                                                                    Pak @jokowi mengubah cara pandang ekonomi. Kini semua orang terhubung, sehingga Indonesia menjadi lebih produktif dan efisien. #MenyatuPutihJokowi
#
# [1815 rows x 2 columns]

# %%
df_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1815 entries, 0 to 1814
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentimen  1815 non-null   object
#  1   tweet     1815 non-null   object
# dtypes: object(2)
# memory usage: 28.5+ KB

# %% [markdown]
# ### Check Validate Rows

# %%
# Cek duplicate rows

duplicate_rows = df_tweets[df_tweets.duplicated(subset='tweet')]

if not duplicate_rows.empty:
    print('Baris duplikat ditemukan: ')
    print(duplicate_rows)
else:
    print('Baris duplikat tidak ditemukan.')
# Out:
# Baris duplikat tidak ditemukan.

# %% [markdown]
# ### Check Imbalance Data

# %% [markdown]
# - Count negative, positive, and netral sentiment
# - Balanced

# %%
sentimen_negatif = df_tweets['sentimen'].value_counts()['negatif']
sentimen_positif = df_tweets['sentimen'].value_counts()['positif']
sentimen_netral = df_tweets['sentimen'].value_counts()['netral']

print('Jumlah sentimen Negatif: ', sentimen_negatif)
print('Jumlah sentimen Positif: ', sentimen_positif)
print('Jumlah sentimen Netral: ', sentimen_netral)
print('Total rows:', df_tweets.shape[0])
# Out:
# Jumlah sentimen Negatif:  596
# Jumlah sentimen Positif:  612
# Jumlah sentimen Netral:  607
# Total rows: 1815

# %% [markdown]
# ### Visualization before Preprocessing Data

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# #### WordCloud

# %% [markdown]
# - Negative Sentiment

# %%
from wordcloud import WordCloud

sentimen_negatif = df_tweets.loc[(df_tweets['sentimen'] == "negatif")]
word_negatif = pd.Series(' '.join(sentimen_negatif['tweet']).split())
text_posi = ' '.join(word_negatif)

wordcloud_neg = WordCloud(background_color='black', mode="RGB", width=1600, height=800, colormap="Dark2").generate(text_posi)
plt.figure(figsize=(10,10))
plt.title('Sentiment Negatif')
plt.imshow(wordcloud_neg)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# - Positive Sentiment

# %%
from wordcloud import WordCloud

sentimen_positif = df_tweets.loc[(df_tweets['sentimen'] == "positif")]
word_positif = pd.Series(' '.join(sentimen_positif['tweet']).split())
text_positif = ' '.join(word_positif)

wordcloud_positif = WordCloud(background_color='black', mode="RGB", width=1600, height=800, colormap="Dark2").generate(text_posi)
plt.figure(figsize=(10,10))
plt.title('Sentiment Positif')
plt.imshow(wordcloud_positif)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# - Netral Sentiment

# %%
from wordcloud import WordCloud

sentimen_netral = df_tweets.loc[(df_tweets['sentimen'] == "netral")]
word_netral = pd.Series(' '.join(sentimen_netral['tweet']).split())
text_netral = ' '.join(word_netral)

wordcloud_netral = WordCloud(background_color='black', mode="RGB", width=1600, height=800, colormap="Dark2").generate(text_posi)
plt.figure(figsize=(10,10))
plt.title('Sentiment Netral')
plt.imshow(wordcloud_netral)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ### Top 10 Words Frequency Before Preprocessing

# %%
from collections import Counter
words = ' '.join(df_tweets['tweet']).split()
word_freq = Counter(words)

common_words = word_freq.most_common(10)
common_words

plt.figure(figsize=(10, 6))
sns.barplot(x=[word[0] for word in common_words], y=[word[1] for word in common_words])
plt.title('Top 10 Kata Paling Umum')
plt.xlabel('Kata')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ## Text Preprocessing & Cleaning

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)

# %% [markdown]
# ###  Regex (Remove URL, Special Character and Punctuation)

# %%
tweet_list = df_tweets['tweet'].tolist()

# %%
def regex_remover(tweet):
    
    #Menghapus pic.twitter.com/
    reg_clean = re.sub(r'pic\.twitter\.com/[\w]+', '', tweet)
    
    #Menghapus Emoji
    reg_clean = re.sub(r'[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U0001FB00-\U0001FBFF\U0001FC00-\U0001FCFF\U0001FD00-\U0001FDFF\U0001FE00-\U0001FEFF\U0001FF00-\U0001FFFF]'
, '', reg_clean)
    
    #Menghapus Karakter Non-ASCII:
    reg_clean = re.sub(r'[^\x00-\x7F]+', '', reg_clean)
    
    #Menghapus Hashtag
    reg_clean = re.sub(r'#\w+', '', reg_clean)
    
    #Menghapus pola @..com
    reg_clean = re.sub(r'via @\w+\.com', '', reg_clean)
    
    #Menghapus pola @
    reg_clean = re.sub(r'@', '', reg_clean)
    
    #Menghapus special character & punctuation, case folding
    reg_clean = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)" ," ",reg_clean.lower()).split())
    
    return reg_clean.strip()

# %%
cleaned_tweet = []

for idx in range(len(tweet_list)):
    cleaned = regex_remover(tweet_list[idx])
    cleaned_tweet.append(cleaned)

print('Hasil sebelumnya')
print('='*50)
display(tweet_list[20:24])
print('Hasil akhir')
print('='*50)
display(cleaned_tweet[20:24])
# Out:
# Hasil sebelumnya
# ==================================================
# ["Assalamu'alaikum.  Saya tahu 1 suara itu sgt berharga dlm upaya memenangkan 02 @prabowo & @sandiuno saya hrs merelakan suara dikarenakan berada di Jkt namun KTP daerah. Semoga suara saya yg tdk disertakan bisa terbalaskan dgn doa. Semoga Allah SWT mengabulkan itu. Aamiin ya Rabb https://twitter.com/sandiuno/status/1117101696696455173Â\xa0â€¦",
#  'Jika Terpilih, Prabowo-Sandiaga Janji Tak Ambil Gaji  -  Kita tahu mereka orang-orang yang superkaya, mbok ya rendah hatilah jangan menyatakan kata2 berkonotasi angkuh !!  https://m.detik.com/news/berita/d-4509616/jika-terpilih-prabowo-sandiaga-janji-tak-ambil-gaji?utm_content=detikcom&utm_term=echobox&utm_medium=oa&utm_campaign=detikcomsocmed&utm_source=Twitter#Echobox=1555171378Â\xa0â€¦',
#  '@prabowo apa bapak  gak menghargai relawan yg puasa dan tirakatan munajad semalam suntuk berdoa untuk kemenangan 02 ? Mhn dibalas tweet dan kontribusi ngopi rokok dll mereka yg  tirakat/mujahadah .Jika tdk maka 02 akan gagal.Ayo semua  tirakat/ munajad.In',
#  'Prabowo sandi menang otomatis kita ikut bersedekah bagi kaum farkir miskin dan dhuafa melalui gaji mereka berfua yg tidak akan diambil dan akan disedekahkan  #17AprilTusukPrabowoSandi']
# Hasil akhir
# ==================================================
# ['assalamu alaikum saya tahu 1 suara itu sgt berharga dlm upaya memenangkan 02 prabowo sandiuno saya hrs merelakan suara dikarenakan berada di jkt namun ktp daerah semoga suara saya yg tdk disertakan bisa terbalaskan dgn doa semoga allah swt mengabulkan itu aamiin ya rabb',
#  'jika terpilih prabowo sandiaga janji tak ambil gaji kita tahu mereka orang orang yang superkaya mbok ya rendah hatilah jangan menyatakan kata2 berkonotasi angkuh',
#  'prabowo apa bapak gak menghargai relawan yg puasa dan tirakatan munajad semalam suntuk berdoa untuk kemenangan 02 mhn dibalas tweet dan kontribusi ngopi rokok dll mereka yg tirakat mujahadah jika tdk maka 02 akan gagal ayo semua tirakat munajad in',
#  'prabowo sandi menang otomatis kita ikut bersedekah bagi kaum farkir miskin dan dhuafa melalui gaji mereka berfua yg tidak akan diambil dan akan disedekahkan']

# %% [markdown]
# ### Replace Slangword

# %%
df_lexicon = pd.read_csv('./colloquial-indonesian-lexicon.csv')
df_lexicon.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow              1
# 1    aminn      amin              1
# 2      met   selamat              1
# 3   netaas   menetas              1
# 4  keberpa  keberapa              0
#
#                                                                                                                                                       context  \
# 0                                                                                                                                                         wow
# 1  Selamat ulang tahun kakak tulus semoga panjang umur kakak,sehat selalu juga,murah rezeki ya kakak dan jangan sombong kalo sukses di karirnya aminn @tulusm
# 2                                                                                                         Met hari netaas kak!? Wish you all the best @tulusm
# 3                                                                                                         Met hari netaas kak!? Wish you all the best @tulusm
# 4                                                                                                                                    Birthday yg keberpa kak?
#
#    category1 category2 category3
# 0   elongasi         0         0
# 1   elongasi         0         0
# 2  abreviasi         0         0
# 3   afiksasi  elongasi         0
# 4  abreviasi         0         0

# %%
# drop kolom yang tidak diperlukan
df_lexicon = df_lexicon.drop(columns=['In-dictionary', 'context', 'category1', 'category2', 'category3'])
df_lexicon
# Out:
#           slang         formal
# 0          woww            wow
# 1         aminn           amin
# 2           met        selamat
# 3        netaas        menetas
# 4       keberpa       keberapa
# ...         ...            ...
# 15001  gataunya  enggak taunya
# 15002      gtau     enggak tau
# 15003     gatau     enggak tau
# 15004     fans2        fan-fan
# 15005   gaharus   enggak harus
#
# [15006 rows x 2 columns]

# %%
slang_dict = dict(zip(df_lexicon['slang'], df_lexicon['formal']))

def replace_slang(text, slang_dict):
    words = text.split()
    replace_words = [slang_dict.get(word, word) for word in words]
    return ' '.join (replace_words)

# %%
new_cleaned_tweet = [replace_slang(text, slang_dict) for text in cleaned_tweet]


print('Hasil sebelumnya')
print('='*50)
display(cleaned_tweet[20:25])
print('Hasil akhir')
print('='*50)
display(new_cleaned_tweet[20:25])
# Out:
# Hasil sebelumnya
# ==================================================
# ['assalamu alaikum saya tahu 1 suara itu sgt berharga dlm upaya memenangkan 02 prabowo sandiuno saya hrs merelakan suara dikarenakan berada di jkt namun ktp daerah semoga suara saya yg tdk disertakan bisa terbalaskan dgn doa semoga allah swt mengabulkan itu aamiin ya rabb',
#  'jika terpilih prabowo sandiaga janji tak ambil gaji kita tahu mereka orang orang yang superkaya mbok ya rendah hatilah jangan menyatakan kata2 berkonotasi angkuh',
#  'prabowo apa bapak gak menghargai relawan yg puasa dan tirakatan munajad semalam suntuk berdoa untuk kemenangan 02 mhn dibalas tweet dan kontribusi ngopi rokok dll mereka yg tirakat mujahadah jika tdk maka 02 akan gagal ayo semua tirakat munajad in',
#  'prabowo sandi menang otomatis kita ikut bersedekah bagi kaum farkir miskin dan dhuafa melalui gaji mereka berfua yg tidak akan diambil dan akan disedekahkan',
#  'kepercayaan hanya diberikan pd mrk yg berpengalaman seorang jokowi memiliki wakil yg berpengalaman dibidang ekonomi coblos yuk 01 ya']
# Hasil akhir
# ==================================================
# ['assalamu alaikum saya tahu 1 suara itu sangat berharga dalam upaya memenangkan 02 prabowo sandiuno saya harus merelakan suara dikarenakan berada di jakarta namun ktp daerah semoga suara saya yang tidak disertakan bisa terbalaskan dengan doa semoga allah swt mengabulkan itu amin ya rabb',
#  'jika terpilih prabowo sandiaga janji tak ambil gaji kita tahu mereka orang orang yang superkaya mbok ya rendah hatilah jangan menyatakan kata-kata berkonotasi angkuh',
#  'prabowo apa bapak enggak menghargai relawan yang puasa dan tirakatan munajad semalam suntuk berdoa untuk kemenangan 02 mhn dibalas tweet dan kontribusi ngopi rokok dll mereka yang tirakat mujahadah jika tidak maka 02 akan gagal ayo semua tirakat munajad ini',
#  'prabowo sandi menang otomatis kita ikut bersedekah bagi kaum farkir miskin dan dhuafa melalui gaji mereka berfua yang tidak akan diambil dan akan disedekahkan',
#  'kepercayaan hanya diberikan pada mereka yang berpengalaman seorang jokowi memiliki wakil yang berpengalaman dibidang ekonomi coblos yuk 01 ya']

# %% [markdown]
# ### Combined with Other Slang

# %%
import json

with open('./combined_slang_words.txt', 'r') as file:
    data = json.load(file)

# %%
df_combined_slang = pd.DataFrame(list(data.items()), columns=["slang", "formal"])
df_combined_slang
# Out:
#       slang            formal
# 0      abis             habis
# 1        ad               ada
# 2      adlh            adalah
# 3     afaik  as far as i know
# 4     ahaha              haha
# ...     ...               ...
# 1030    via             lewat
# 1031    sdh             sudah
# 1032    org             orang
# 1033     ma              sama
# 1034     gk             tidak
#
# [1035 rows x 2 columns]

# %%
slang_dict = dict(zip(df_combined_slang['slang'], df_combined_slang['formal']))

def combined_new_slang(text, slang_dict):
    words = text.split()
    combined_new_words = [slang_dict.get(word, word) for word in words]
    return ' '.join (combined_new_words)

# %%
combined_tweet = [combined_new_slang(text, slang_dict) for text in new_cleaned_tweet]


print('Hasil sebelumnya')
print('='*50)
display(new_cleaned_tweet[20:25])
print('Hasil akhir')
print('='*50)
display(combined_tweet[20:25])
# Out:
# Hasil sebelumnya
# ==================================================
# ['assalamu alaikum saya tahu 1 suara itu sangat berharga dalam upaya memenangkan 02 prabowo sandiuno saya harus merelakan suara dikarenakan berada di jakarta namun ktp daerah semoga suara saya yang tidak disertakan bisa terbalaskan dengan doa semoga allah swt mengabulkan itu amin ya rabb',
#  'jika terpilih prabowo sandiaga janji tak ambil gaji kita tahu mereka orang orang yang superkaya mbok ya rendah hatilah jangan menyatakan kata-kata berkonotasi angkuh',
#  'prabowo apa bapak enggak menghargai relawan yang puasa dan tirakatan munajad semalam suntuk berdoa untuk kemenangan 02 mhn dibalas tweet dan kontribusi ngopi rokok dll mereka yang tirakat mujahadah jika tidak maka 02 akan gagal ayo semua tirakat munajad ini',
#  'prabowo sandi menang otomatis kita ikut bersedekah bagi kaum farkir miskin dan dhuafa melalui gaji mereka berfua yang tidak akan diambil dan akan disedekahkan',
#  'kepercayaan hanya diberikan pada mereka yang berpengalaman seorang jokowi memiliki wakil yang berpengalaman dibidang ekonomi coblos yuk 01 ya']
# Hasil akhir
# ==================================================
# ['assalamu alaikum saya tahu 1 suara itu sangat berharga dalam upaya memenangkan 02 prabowo sandiuno saya harus merelakan suara dikarenakan berada di jakarta namun ktp daerah semoga suara saya yang tidak disertakan bisa terbalaskan dengan doa semoga allah swt mengabulkan itu amin iya rabb',
#  'jika terpilih prabowo sandiaga janji tidak ambil gaji kita tahu mereka orang orang yang superkaya mbok iya rendah hatilah jangan menyatakan kata-kata berkonotasi angkuh',
#  'prabowo apa bapak tidak menghargai relawan yang puasa dan tirakatan munajad semalam suntuk berdoa untuk kemenangan 02 mohon dibalas tweet dan kontribusi ngopi rokok dan lain-lain mereka yang tirakat mujahadah jika tidak maka 02 akan gagal ayo semua tirakat munajad ini',
#  'prabowo sandi menang otomatis kita ikut bersedekah bagi kaum farkir miskin dan dhuafa melalui gaji mereka berfua yang tidak akan diambil dan akan disedekahkan',
#  'kepercayaan hanya diberikan pada mereka yang berpengalaman seorang jokowi memiliki wakil yang berpengalaman dibidang ekonomi coblos yuk 01 iya']

# %% [markdown]
# ## EDA After Preprocessing

# %%
df_tweets['preproceed_tweet'] = combined_tweet
df_tweets
# Out:
#      sentimen  \
# 0     negatif
# 1      netral
# 2      netral
# 3     positif
# 4     negatif
# ...       ...
# 1810   netral
# 1811   netral
# 1812   netral
# 1813   netral
# 1814   netral
#
#                                                                                                                                                                                                                                                      tweet  \
# 0                                                      Kata @prabowo Indonesia tidak dihargai bangsa asing!   Berita ini ðŸ‘‡ pasti hoax buatan penguasa, ya kan @rockygerung?ðŸ˜œ https://twitter.com/mediaindonesia/status/1117575436337160192?s=21Â â€¦
# 1                                                                                                                                                            Batuan Langka, Tasbih Jokowi Hadiah dari Habib Luthfi Seharga Mercy?  http://dlvr.it/R2pvZVÂ
# 2                                                                                                                           Di era Jokowi, ekonomi Indonesia semakin baik. #01IndonesiaMaju #JokowiLagi #JokowiMenangTotalDebat pic.twitter.com/W2ythnxsTp
# 3                                                                                                                         Bagi Sumatera Selatan, Asian Games berdampak pd ekonomi langsung diprediksi mencapai 18,5 triliun. Indonesia maju, Jokowi hebat!
# 4     Negara kita ngutang buat bngun infrastruktur yang udah dipake masyarakat, terus masyarakatnya ngeluh karena negara ngutang, setiap negara itu pasti ngutang,  utang bisa dibayar kalo negara dapet penghasilan. Penghasilan negara itu ya dari pajak
# ...                                                                                                                                                                                                                                                    ...
# 1810                                                                                                                                                   Negarawan sejati sll bangga dan mengedepankan harga diri bangsanya yg berdaulat  #2019GantiPresiden
# 1811                                                                                                                                                                      1. HRS ceramah di Damai Indonesiaku 2. Perekonomian makin membaik.  #PutihkanGBK
# 1812                                                                                                  Mari bangun bangsa dgn mendukung perekonomian negara bersama Pak Jokowi. Ayo kerja!  https://twitter.com/KaskusLoker/status/1111643312241295363Â â€¦
# 1813                                                                                                                             Bantu majukan perekonomian bangsa bersama Pak Jokowi, yuk!  https://twitter.com/BKNSquare/status/1113655944955588610Â â€¦
# 1814                                                                                                    Pak @jokowi mengubah cara pandang ekonomi. Kini semua orang terhubung, sehingga Indonesia menjadi lebih produktif dan efisien. #MenyatuPutihJokowi
#
#                                                                                                                                                                                                                                        preproceed_tweet
# 0                                                                                                                                    kata prabowo indonesia tidak dihargai bangsa asing berita ini pasti isu bohong buatan penguasa iya kan rockygerung
# 1                                                                                                                                                                                    batuan langka tasbih jokowi hadiah dari habib luthfi seharga mercy
# 2                                                                                                                                                                                                          di era jokowi ekonomi indonesia semakin baik
# 3                                                                                                                        bagi sumatera selatan asian games berdampak pada ekonomi langsung diprediksi mencapai 18 5 triliun indonesia maju jokowi hebat
# 4     negara kita hutang buat bangun infrastruktur yang sudah dipakai masyarakat terus masyarakatnya ngeluh karena negara hutang setiap negara itu pasti hutang utang bisa dibayar kalau negara dapat penghasilan penghasilan negara itu iya dari pajak
# ...                                                                                                                                                                                                                                                 ...
# 1810                                                                                                                                                               negarawan sejati selalu bangga dan mengedepankan harga diri bangsanya yang berdaulat
# 1811                                                                                                                                                                                  1 harus ceramah di damai indonesiaku 2 perekonomian makin membaik
# 1812                                                                                                                                                             mari bangun bangsa dengan mendukung perekonomian negara bersama bapak jokowi ayo kerja
# 1813                                                                                                                                                                                         bantu majukan perekonomian bangsa bersama bapak jokowi yuk
# 1814                                                                                                                       bapak jokowi mengubah cara pandang ekonomi kini semua orang terhubung sehingga indonesia menjadi lebih produktif dan efisien
#
# [1815 rows x 3 columns]

# %% [markdown]
# ### Visualization after Preprocessing Data

# %% [markdown]
# #### WordCloud

# %% [markdown]
# - Negative Sentiment

# %%
from wordcloud import WordCloud

cleaned_sentimen_negatif = df_tweets.loc[(df_tweets['sentimen'] == "negatif")]
cleaned_word_negatif = pd.Series(' '.join(cleaned_sentimen_negatif['preproceed_tweet']).split())
cleaned_text_neg = ' '.join(cleaned_word_negatif)

cleaned_wordcloud_neg = WordCloud(background_color='black', mode="RGB", width=1600, height=800, colormap="Dark2").generate(text_posi)
plt.figure(figsize=(10,10))
plt.title('Sentiment Negatif')
plt.imshow(cleaned_wordcloud_neg)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# - Positive Sentiment

# %%
from wordcloud import WordCloud

cleaned_sentimen_positif = df_tweets.loc[(df_tweets['sentimen'] == "positif")]
cleaned_word_positif = pd.Series(' '.join(cleaned_sentimen_positif['preproceed_tweet']).split())
cleaned_text_pos = ' '.join(cleaned_word_positif)

cleaned_wordcloud_pos = WordCloud(background_color='black', mode="RGB", width=1600, height=800, colormap="Dark2").generate(text_posi)
plt.figure(figsize=(10,10))
plt.title('Sentiment Positif')
plt.imshow(cleaned_wordcloud_pos)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# - Netral Sentiment

# %%
from wordcloud import WordCloud

cleaned_sentimen_netral = df_tweets.loc[(df_tweets['sentimen'] == "netral")]
cleaned_word_netral = pd.Series(' '.join(cleaned_sentimen_netral['preproceed_tweet']).split())
cleaned_text_net = ' '.join(cleaned_word_netral)

cleaned_wordcloud_net = WordCloud(background_color='black', mode="RGB", width=1600, height=800, colormap="Dark2").generate(text_posi)
plt.figure(figsize=(10,10))
plt.title('Sentiment Netral')
plt.imshow(cleaned_wordcloud_net)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ### Top 10 Word Frequency After Prepropcessing

# %%
from collections import Counter
words = ' '.join(df_tweets['preproceed_tweet']).split()
word_freq = Counter(words)

common_words = word_freq.most_common(10)
common_words

plt.figure(figsize=(10, 6))
sns.barplot(x=[word[0] for word in common_words], y=[word[1] for word in common_words])
plt.title('Top 10 Kata Paling Umum')
plt.xlabel('Kata')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Pada beberapa percobaan sebelumnya, saya sudah melakukan stopwords, untuk itu di sini tidak saya lakukan lagi karena berpotensi menyebabkan pergeseran makna kalimat. Contoh:
#
# Sebelum Stopword:
# - kata prabowo indonesia tidak dihargai bangsa asing berita ini pasti hoax buatan penguasa ya kan rockygerung
#
# Setelah Stopword:
# - kata prabowo indonesia dihargai bangsa asing berita ini pasti hoax buatan penguasa ya kan rockygerung
#
# Setelah stopword, kata 'tidak' jadi dihilangkan. Ini akan mengubah sentimen yang tadinya negatif, bisa menjadi positif atau netral. Maka dari itu, saya tidak menggunakan stopword

# %% [markdown]
# ## Text Normalization

# %% [markdown]
# - Proses stemming menggunakan Sastrawi ini bisa memakan 15-20 menit sekali eksekusi

# %% [markdown]
# ### Stemming Sastrawi

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /Users/tatauntoro/anaconda3/lib/python3.11/site-packages (1.0.1)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
def stemming_indonesian_sastrawi(tweet):
  
    stemmer = StemmerFactory().create_stemmer()
    
    
    stemmed_text = stemmer.stem(tweet)
    return stemmed_text

# %%
stemmed_tweets = []

for idx in range(len(combined_tweet)):
    stemmed = stemming_indonesian_sastrawi(combined_tweet[idx])
    stemmed_tweets.append(stemmed)
    
print('Hasil sebelumnya')
print('='*50)
display(combined_tweet[190:199])
print('Hasil akhir')
print('='*50)
display(stemmed_tweets[190:199])
# Out:
# Hasil sebelumnya
# ==================================================
# ['lalu harga tiket pesawat kapan diturunkan bapak saya sangat brharap besar dalam aspek ini trlbh dengan mahal nya harga tiket pesawat terbang yang amat tinggi mahal tarif biaya expdisi antar kota pun ikut melonjak naik',
#  'paling parah malaysia mbak bayangkan 2jt orang harus beetumpu di 3 tps apakah kita sebagai warga negara tidak boleh kritik dan tidak boleh marah kalau lihat para pelaksana swperti itu sedangkan mereka di gaji olh uang negara',
#  'iya daripada memikirkan yang kayak begitu lebih baik memikirkan hal yang mendasar dulu dong ekonomi dan lain-lain lah kalau ketagihan game online bikin malas sgl nya di suruh wirid ke masjid bahkan nongkrong di warnet bergayalah sesuai isi kantong',
#  'kata die zaman jokowi ekonomi anjlok tapi punya gadget sebanyak itu belum lagi bayar wifi terus dia bilang anjlok dan serba mahal itu apa',
#  'janji tidak ambil gaji jika terpilih prabowo sandi ikuti jejak para presiden terkenal ini',
#  'iya memang lebih kecil tapi pngetahuan tata kelola ekonomi negara jauh kelasnya',
#  'prabowo sudah berbuat apa untuk rakyat kecil sedang gaji karyawannya saja belum dibayar sampai sekarang heheheheee',
#  'akui kekurangan iya akui prabowo dulu kristen sekarang mualaf ibunya kristen hashim kristen tidak bisa sholat wudhu gerakan salah tidak bisa mengaji dipecat dari tni 1 dari elit bajingan',
#  'prabowo dan sandi berniat tidak ambil gaji kalau menjabat ini memang gayanya donald trump dia memang gakmau digaji iya sudah kaya mau bagaimana lagi']
# Hasil akhir
# ==================================================
# ['lalu harga tiket pesawat kapan turun bapak saya sangat brharap besar dalam aspek ini trlbh dengan mahal nya harga tiket pesawat terbang yang amat tinggi mahal tarif biaya expdisi antar kota pun ikut lonjak naik',
#  'paling parah malaysia mbak bayang 2jt orang harus beetumpu di 3 tps apakah kita bagai warga negara tidak boleh kritik dan tidak boleh marah kalau lihat para laksana swperti itu sedang mereka di gaji olh uang negara',
#  'iya daripada pikir yang kayak begitu lebih baik pikir hal yang dasar dulu dong ekonomi dan lain lah kalau tagih game online bikin malas sgl nya di suruh wirid ke masjid bahkan nongkrong di warnet gaya sesuai isi kantong',
#  'kata die zaman jokowi ekonomi anjlok tapi punya gadget banyak itu belum lagi bayar wifi terus dia bilang anjlok dan serba mahal itu apa',
#  'janji tidak ambil gaji jika pilih prabowo sandi ikut jejak para presiden kenal ini',
#  'iya memang lebih kecil tapi pngetahuan tata kelola ekonomi negara jauh kelas',
#  'prabowo sudah buat apa untuk rakyat kecil sedang gaji karyawannya saja belum bayar sampai sekarang heheheheee',
#  'aku kurang iya aku prabowo dulu kristen sekarang mualaf ibu kristen hashim kristen tidak bisa sholat wudhu gera salah tidak bisa aji pecat dari tni 1 dari elit bajing',
#  'prabowo dan sandi niat tidak ambil gaji kalau jabat ini memang gaya donald trump dia memang gakmau gaji iya sudah kaya mau bagaimana lagi']

# %% [markdown]
# ## After Stemming

# %%
df_tweets['stemmed_tweet'] = stemmed_tweets
df_tweets
# Out:
#      sentimen  \
# 0     negatif
# 1      netral
# 2      netral
# 3     positif
# 4     negatif
# ...       ...
# 1810   netral
# 1811   netral
# 1812   netral
# 1813   netral
# 1814   netral
#
#                                                                                                                                                                                                                                                      tweet  \
# 0                                                      Kata @prabowo Indonesia tidak dihargai bangsa asing!   Berita ini ðŸ‘‡ pasti hoax buatan penguasa, ya kan @rockygerung?ðŸ˜œ https://twitter.com/mediaindonesia/status/1117575436337160192?s=21Â â€¦
# 1                                                                                                                                                            Batuan Langka, Tasbih Jokowi Hadiah dari Habib Luthfi Seharga Mercy?  http://dlvr.it/R2pvZVÂ
# 2                                                                                                                           Di era Jokowi, ekonomi Indonesia semakin baik. #01IndonesiaMaju #JokowiLagi #JokowiMenangTotalDebat pic.twitter.com/W2ythnxsTp
# 3                                                                                                                         Bagi Sumatera Selatan, Asian Games berdampak pd ekonomi langsung diprediksi mencapai 18,5 triliun. Indonesia maju, Jokowi hebat!
# 4     Negara kita ngutang buat bngun infrastruktur yang udah dipake masyarakat, terus masyarakatnya ngeluh karena negara ngutang, setiap negara itu pasti ngutang,  utang bisa dibayar kalo negara dapet penghasilan. Penghasilan negara itu ya dari pajak
# ...                                                                                                                                                                                                                                                    ...
# 1810                                                                                                                                                   Negarawan sejati sll bangga dan mengedepankan harga diri bangsanya yg berdaulat  #2019GantiPresiden
# 1811                                                                                                                                                                      1. HRS ceramah di Damai Indonesiaku 2. Perekonomian makin membaik.  #PutihkanGBK
# 1812                                                                                                  Mari bangun bangsa dgn mendukung perekonomian negara bersama Pak Jokowi. Ayo kerja!  https://twitter.com/KaskusLoker/status/1111643312241295363Â â€¦
# 1813                                                                                                                             Bantu majukan perekonomian bangsa bersama Pak Jokowi, yuk!  https://twitter.com/BKNSquare/status/1113655944955588610Â â€¦
# 1814                                                                                                    Pak @jokowi mengubah cara pandang ekonomi. Kini semua orang terhubung, sehingga Indonesia menjadi lebih produktif dan efisien. #MenyatuPutihJokowi
#
#                                                                                                                                                                                                                                        preproceed_tweet  \
# 0                                                                                                                                    kata prabowo indonesia tidak dihargai bangsa asing berita ini pasti isu bohong buatan penguasa iya kan rockygerung
# 1                                                                                                                                                                                    batuan langka tasbih jokowi hadiah dari habib luthfi seharga mercy
# 2                                                                                                                                                                                                          di era jokowi ekonomi indonesia semakin baik
# 3                                                                                                                        bagi sumatera selatan asian games berdampak pada ekonomi langsung diprediksi mencapai 18 5 triliun indonesia maju jokowi hebat
# 4     negara kita hutang buat bangun infrastruktur yang sudah dipakai masyarakat terus masyarakatnya ngeluh karena negara hutang setiap negara itu pasti hutang utang bisa dibayar kalau negara dapat penghasilan penghasilan negara itu iya dari pajak
# ...                                                                                                                                                                                                                                                 ...
# 1810                                                                                                                                                               negarawan sejati selalu bangga dan mengedepankan harga diri bangsanya yang berdaulat
# 1811                                                                                                                                                                                  1 harus ceramah di damai indonesiaku 2 perekonomian makin membaik
# 1812                                                                                                                                                             mari bangun bangsa dengan mendukung perekonomian negara bersama bapak jokowi ayo kerja
# 1813                                                                                                                                                                                         bantu majukan perekonomian bangsa bersama bapak jokowi yuk
# 1814                                                                                                                       bapak jokowi mengubah cara pandang ekonomi kini semua orang terhubung sehingga indonesia menjadi lebih produktif dan efisien
#
#                                                                                                                                                                                                                      stemmed_tweet
# 0                                                                                                                       kata prabowo indonesia tidak harga bangsa asing berita ini pasti isu bohong buat kuasa iya kan rockygerung
# 1                                                                                                                                                                   batu langka tasbih jokowi hadiah dari habib luthfi harga mercy
# 2                                                                                                                                                                                       di era jokowi ekonomi indonesia makin baik
# 3                                                                                                             bagi sumatera selatan asi games dampak pada ekonomi langsung prediksi capai 18 5 triliun indonesia maju jokowi hebat
# 4     negara kita hutang buat bangun infrastruktur yang sudah pakai masyarakat terus masyarakat ngeluh karena negara hutang tiap negara itu pasti hutang utang bisa bayar kalau negara dapat hasil hasil negara itu iya dari pajak
# ...                                                                                                                                                                                                                            ...
# 1810                                                                                                                                                        negarawan sejati selalu bangga dan depan harga diri bangsa yang daulat
# 1811                                                                                                                                                                       1 harus ceramah di damai indonesia 2 ekonomi makin baik
# 1812                                                                                                                                                   mari bangun bangsa dengan dukung ekonomi negara sama bapak jokowi ayo kerja
# 1813                                                                                                                                                                               bantu maju ekonomi bangsa sama bapak jokowi yuk
# 1814                                                                                                            bapak jokowi ubah cara pandang ekonomi kini semua orang hubung sehingga indonesia jadi lebih produktif dan efisien
#
# [1815 rows x 4 columns]

# %% [markdown]
# ### Filter by Negative Sentiment

# %%
negative_sentiment = df_tweets[df_tweets['sentimen'] == 'negatif']
negative_sentiment.head()
# Out:
#    sentimen  \
# 0   negatif
# 4   negatif
# 9   negatif
# 12  negatif
# 21  negatif
#
#                                                                                                                                                                                                                                                                                                                                                                                                    tweet  \
# 0                                                                                                                                                                                                    Kata @prabowo Indonesia tidak dihargai bangsa asing!   Berita ini ðŸ‘‡ pasti hoax buatan penguasa, ya kan @rockygerung?ðŸ˜œ https://twitter.com/mediaindonesia/status/1117575436337160192?s=21Â â€¦
# 4                                                                                                                                                   Negara kita ngutang buat bngun infrastruktur yang udah dipake masyarakat, terus masyarakatnya ngeluh karena negara ngutang, setiap negara itu pasti ngutang,  utang bisa dibayar kalo negara dapet penghasilan. Penghasilan negara itu ya dari pajak
# 9                                                                                                                                                         Prabowo-Sandi Sepakat Tak Ambil Gaji karena Negara Sedang Susah  https://www.goaceh.co/artikel/serbaserbi/2019/04/14/prabowosandi-sepakat-tak-ambil-gaji-karena-negara-sedang-susah/?utm_source=dlvr.it&utm_medium=twitterÂ â€¦ .. ... #GoAceh
# 12                                                                                                                                                                                                                                                                    Gak nginti Lu to @yunartowijaya, dan si @AT_AbdillahToha juga gak ngacaaa,, Gak usah ngajarin Sandi soal ekonomi dibanding Jokowi.
# 21  Jika Terpilih, Prabowo-Sandiaga Janji Tak Ambil Gaji  -  Kita tahu mereka orang-orang yang superkaya, mbok ya rendah hatilah jangan menyatakan kata2 berkonotasi angkuh !!  https://m.detik.com/news/berita/d-4509616/jika-terpilih-prabowo-sandiaga-janji-tak-ambil-gaji?utm_content=detikcom&utm_term=echobox&utm_medium=oa&utm_campaign=detikcomsocmed&utm_source=Twitter#Echobox=1555171378Â â€¦
#
#                                                                                                                                                                                                                                      preproceed_tweet  \
# 0                                                                                                                                  kata prabowo indonesia tidak dihargai bangsa asing berita ini pasti isu bohong buatan penguasa iya kan rockygerung
# 4   negara kita hutang buat bangun infrastruktur yang sudah dipakai masyarakat terus masyarakatnya ngeluh karena negara hutang setiap negara itu pasti hutang utang bisa dibayar kalau negara dapat penghasilan penghasilan negara itu iya dari pajak
# 9                                                                                                                                                                                   prabowo sandi sepakat tidak ambil gaji karena negara sedang susah
# 12                                                                                                          tidak nginti kamu tapi yunartowijaya dan sih at abdillahtoha juga tidak mengaca tidak perlu mengajari sandi soal ekonomi dibanding jokowi
# 21                                                                           jika terpilih prabowo sandiaga janji tidak ambil gaji kita tahu mereka orang orang yang superkaya mbok iya rendah hatilah jangan menyatakan kata-kata berkonotasi angkuh
#
#                                                                                                                                                                                                                    stemmed_tweet
# 0                                                                                                                     kata prabowo indonesia tidak harga bangsa asing berita ini pasti isu bohong buat kuasa iya kan rockygerung
# 4   negara kita hutang buat bangun infrastruktur yang sudah pakai masyarakat terus masyarakat ngeluh karena negara hutang tiap negara itu pasti hutang utang bisa bayar kalau negara dapat hasil hasil negara itu iya dari pajak
# 9                                                                                                                                                              prabowo sandi sepakat tidak ambil gaji karena negara sedang susah
# 12                                                                                               tidak nginti kamu tapi yunartowijaya dan sih at abdillahtoha juga tidak kaca tidak perlu ajar sandi soal ekonomi banding jokowi
# 21                                                                         jika pilih prabowo sandiaga janji tidak ambil gaji kita tahu mereka orang orang yang superkaya mbok iya rendah hati jangan nyata kata konotasi angkuh

# %% [markdown]
# ### Filter by Positive Sentiment

# %%
positive_sentiment = df_tweets[df_tweets['sentimen'] == 'positif']
positive_sentiment.head()
# Out:
#    sentimen  \
# 3   positif
# 6   positif
# 7   positif
# 10  positif
# 11  positif
#
#                                                                                                                                                                                                                                                        tweet  \
# 3                                                                                                                           Bagi Sumatera Selatan, Asian Games berdampak pd ekonomi langsung diprediksi mencapai 18,5 triliun. Indonesia maju, Jokowi hebat!
# 6                                                                                                                                                                                                      Masa tenang msih ngoceh aja..ttp jokowi harga mati...
# 7                                                                                                         #UASdifitnahKejiBalasDiTPS   kerjasa ekonomi bilateral, multilateral kita doakan di TPS sambil dengarkan suara hati...  #UASdifitnahKejiBalasDiTPS
# 10                            #PilihOrangBaik #PilihJelasIslamnya #PilihBajuPutih Pilih pemimpin itu yg udh jelas banyak pencapaiannya. Nah, ini dia 5 pencapaian ekonomi selama pemerintahan Jokowi. Coblos 01 Yuk Kerja Pasti !   https://bit.ly/2OgymxtÂ
# 11  Calon presiden Jokowi menjelaskan program Kartu Pra Kerja akan memberikan insentif dalam kurun waktu tertentu, bukan berarti memberikan gaji secara cuma-cuma bagi masyarakat yang belum berpenghasilan. #2019JokowiKyaiMaruf pic.twitter.com/Nj2hhmiIzv
#
#                                                                                                                                                                                           preproceed_tweet  \
# 3                                                                           bagi sumatera selatan asian games berdampak pada ekonomi langsung diprediksi mencapai 18 5 triliun indonesia maju jokowi hebat
# 6                                                                                                                                                  masa tenang masih mengoceh saja tetap jokowi harga mati
# 7                                                                                                                    kerjasa ekonomi bilateral multilateral kita doakan di tps sambil dengarkan suara hati
# 10                                                          pilih pemimpin itu yang sudah jelas banyak pencapaiannya nah ini dia 5 pencapaian ekonomi selama pemerintahan jokowi coblos 01 yuk kerja pasti
# 11  calon presiden jokowi menjelaskan program kartu pra kerja akan memberikan insentif dalam kurun waktu tertentu bukan berarti memberikan gaji secara cuma cuma bagi masyarakat yang belum berpenghasilan
#
#                                                                                                                                                           stemmed_tweet
# 3                                                  bagi sumatera selatan asi games dampak pada ekonomi langsung prediksi capai 18 5 triliun indonesia maju jokowi hebat
# 6                                                                                                                   masa tenang masih oceh saja tetap jokowi harga mati
# 7                                                                                       kerjasa ekonomi bilateral multilateral kita doa di tps sambil dengar suara hati
# 10                                            pilih pimpin itu yang sudah jelas banyak capai nah ini dia 5 capai ekonomi lama perintah jokowi coblos 01 yuk kerja pasti
# 11  calon presiden jokowi jelas program kartu pra kerja akan beri insentif dalam kurun waktu tentu bukan arti beri gaji cara cuma cuma bagi masyarakat yang belum hasil

# %% [markdown]
# ### Filter by Netral Sentiment

# %%
netral_sentiment = df_tweets[df_tweets['sentimen'] == 'netral']
netral_sentiment.head()
# Out:
#    sentimen  \
# 1    netral
# 2    netral
# 5    netral
# 8    netral
# 14   netral
#
#                                                                                                                                                                                                                                                                                             tweet  \
# 1                                                                                                                                                                                                   Batuan Langka, Tasbih Jokowi Hadiah dari Habib Luthfi Seharga Mercy?  http://dlvr.it/R2pvZVÂ
# 2                                                                                                                                                                  Di era Jokowi, ekonomi Indonesia semakin baik. #01IndonesiaMaju #JokowiLagi #JokowiMenangTotalDebat pic.twitter.com/W2ythnxsTp
# 5            Yg bisikin pak jokowi, cm mikirin perputaran duit di golongan tertentu. E-Sports hanya sebagian kecil dr sekian besar penentu pertumbuhan perekonomian Indonesia, bukan hal fundamental. Betul yg dikatakan prabowo, walau dgn bhs yg sederhana, tp mrpkan aspek fundamental ekonomi
# 8   Iya bener Aa, kita MANTAP kan pilihan ke Pemimpin yg bs memberi Solusi @jokowi bukan yg menyalahkan pemimpin sebelumnya @SBYudhoyono dismash sm mas Bowo, percuma koalisi klau mengantam tmn koalisi ðŸ˜‚ & yg plg penting pilih Pemimpin yg Rajin Ibadah Wajib, Bisa NGAJI & JumatanðŸ™ðŸ‘
# 14                                                                                                                                                                                                                       Terlalu berat nge bahas ekonomi dgn angka2.. Cukup bahas mobil lejen aj,
#
#                                                                                                                                                                                                                                                                                          preproceed_tweet  \
# 1                                                                                                                                                                                                                                      batuan langka tasbih jokowi hadiah dari habib luthfi seharga mercy
# 2                                                                                                                                                                                                                                                            di era jokowi ekonomi indonesia semakin baik
# 5   yang bisikin bapak jokowi cuma memikirkan perputaran duit di golongan tertentu e sports hanya sebagian kecil dari sekian besar penentu pertumbuhan perekonomian indonesia bukan hal fundamental betul yang dikatakan prabowo walau dengan bahasa yang sederhana tapi mrpkan aspek fundamental ekonomi
# 8             iya benar aa kita mantap kan pilihan ke pemimpin yang bisa memberi solusi jokowi bukan yang menyalahkan pemimpin sebelumnya sbyudhoyono dismash sama mas bowo percuma koalisi kalau mengantam teman koalisi yang pulang penting pilih pemimpin yang rajin ibadah wajib bisa mengaji jumatan
# 14                                                                                                                                                                                                                             terlalu berat nge bahas ekonomi dengan angka2 cukup bahas mobil lejen saja
#
#                                                                                                                                                                                                                                                         stemmed_tweet
# 1                                                                                                                                                                                                      batu langka tasbih jokowi hadiah dari habib luthfi harga mercy
# 2                                                                                                                                                                                                                          di era jokowi ekonomi indonesia makin baik
# 5   yang bisikin bapak jokowi cuma pikir putar duit di golong tentu e sports hanya bagi kecil dari sekian besar tentu tumbuh ekonomi indonesia bukan hal fundamental betul yang kata prabowo walau dengan bahasa yang sederhana tapi mrpkan aspek fundamental ekonomi
# 8     iya benar aa kita mantap kan pilih ke pimpin yang bisa beri solusi jokowi bukan yang salah pimpin belum sbyudhoyono dismash sama mas bowo percuma koalisi kalau mengantam teman koalisi yang pulang penting pilih pimpin yang rajin ibadah wajib bisa aji jumat
# 14                                                                                                                                                                                         terlalu berat nge bahas ekonomi dengan angka2 cukup bahas mobil lejen saja

# %% [markdown]
# ### Word Tokenization

# %% [markdown]
# Saya mencoba melakukan word tokenization hasil dari Stemming, yang nantinya digunakan untuk menghitung Top 10 Word Frequency.

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')

def tokenization_word(tweet):
    
    # Melakukan Word Tokenization
    tokens = word_tokenize(tweet)
    return tokens
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/tatauntoro/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
word_tokenized = []

for idx in range(len(stemmed_tweets)):
    tokenized = tokenization_word(stemmed_tweets[idx])
    word_tokenized.append(tokenized)

print("Hasil sebelumnya")
print("="*50)
display(stemmed_tweets[:1])
print("Hasil akhir")
print("="*50)
display(word_tokenized[:1])
# Out:
# Hasil sebelumnya
# ==================================================
# ['kata prabowo indonesia tidak harga bangsa asing berita ini pasti isu bohong buat kuasa iya kan rockygerung']
# Hasil akhir
# ==================================================
# [['kata',
#   'prabowo',
#   'indonesia',
#   'tidak',
#   'harga',
#   'bangsa',
#   'asing',
#   'berita',
#   'ini',
#   'pasti',
#   'isu',
#   'bohong',
#   'buat',
#   'kuasa',
#   'iya',
#   'kan',
#   'rockygerung']]

# %% [markdown]
# ## Top 10 Word Frequency Based on Word Tokenization

# %%
import itertools
from collections import Counter, OrderedDict

tweet_words_tokenized_flattened = list(itertools.chain(*word_tokenized))
tokenized_words_counts = Counter(tweet_words_tokenized_flattened)
tokenized_words_sorted = OrderedDict(sorted(tokenized_words_counts.items(), key = lambda kv : kv[1], reverse = False))

# %%
plt.figure(figsize=(8, 4))
font_title = {'family': 'serif', 'color': 'maroon', 'size': 20}

plt.barh(
    list(tokenized_words_sorted.keys())[-10:],
    list(tokenized_words_sorted.values())[-10:], color= 'pink'
)

plt.title('Top 10 word frequency:\nSentiment Pemilu 2019', fontdict=font_title)
plt.show()

# %% [markdown]
# ## Preparing for Train Model

# %% [markdown]
# ### Tokenizing, Vectorizing and Split Data

# %% [markdown]
# Based on Stemming (Di sini saya melakukan percobaan menggunakan data yang sudah di-stemming)

# %%
max_words = 1000
max_len = 150

#Tokenize
tokenizer = Tokenizer(oov_token='UNK', num_words=max_words, lower=True)
tokenizer.fit_on_texts(df_tweets['stemmed_tweet'].values)
word_index = tokenizer.word_index

#Vectorize to X, and define Y
X = tokenizer.texts_to_sequences(df_tweets['stemmed_tweet'].values)
X = pad_sequences(X, maxlen=max_len)
print('X shape: ', X.shape)

Y = data_tweet_dropped['sentimen']
print('Y shape: ', Y.shape)
# Out:
# X shape:  (1815, 150)
# Y shape:  (1815,)

# %%
#Label Encoder
label_encoder = LabelEncoder()
Y_encoded = label_encoder.fit_transform(Y)

# Onehot encoding 
Y_one_hot = to_categorical(Y_encoded, num_classes=3)

# %%
X_train, X_test, Y_train_one_hot, Y_test_one_hot = train_test_split(X, Y_one_hot, test_size=0.3, random_state=0)

# %%
print(len(X))
print(len(Y))
print(len(X_train))
print(len(X_test))
print(len(Y_train_one_hot))
print(len(Y_test_one_hot))
# Out:
# 1815
# 1815
# 1270
# 545
# 1270
# 545

# %% [markdown]
# ## Build Architecture Model Using LSTM Algorithm

# %%
def RNN():
    inputs = Input(name='inputs', shape=[max_len])
    layer = Embedding(max_words, 50, input_length=max_len)(inputs)
    layer = LSTM(144)(layer)
    layer = Dense(32, kernel_regularizer=regularizers.l1(0.001), name='FC1')(layer)
    layer = Dense(32, kernel_initializer=he_normal(seed=42))(layer)
    layer = Dense(32, name='FC2')(layer)
    layer = Dense(32, activation='relu')(layer)
    layer = Dropout(0.2)(layer)
    layer = BatchNormalization()(layer)
    layer = Dense(3, activation='softmax')(layer)
    model = Model(inputs=inputs, outputs=layer)
    return model

# %%
adam_optimizer = Adam(learning_rate=0.0001)
model = RNN()
model.summary
model.compile(loss='categorical_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001, min_delta=0.0001)

model.fit(X_train, Y_train_one_hot,
         epochs=30, batch_size=138, validation_split=0.2,
         validation_data=(X_test, Y_test_one_hot),
         callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# 10/10 [==============================] - 3s 258ms/step - loss: 1.5291 - accuracy: 0.3583 - val_loss: 1.5227 - val_accuracy: 0.3468 - lr: 1.0000e-04
# Epoch 2/30
# 10/10 [==============================] - 2s 230ms/step - loss: 1.4811 - accuracy: 0.4457 - val_loss: 1.5197 - val_accuracy: 0.4000 - lr: 1.0000e-04
# Epoch 3/30
# 10/10 [==============================] - 2s 232ms/step - loss: 1.4601 - accuracy: 0.4575 - val_loss: 1.5170 - val_accuracy: 0.4349 - lr: 1.0000e-04
# Epoch 4/30
# 10/10 [==============================] - 2s 247ms/step - loss: 1.4421 - accuracy: 0.4898 - val_loss: 1.5142 - val_accuracy: 0.4917 - lr: 1.0000e-04
# Epoch 5/30
# 10/10 [==============================] - 2s 234ms/step - loss: 1.4230 - accuracy: 0.5008 - val_loss: 1.5118 - val_accuracy: 0.4917 - lr: 1.0000e-04
# Epoch 6/30
# 10/10 [==============================] - 2s 228ms/step - loss: 1.3992 - accuracy: 0.5213 - val_loss: 1.5089 - val_accuracy: 0.5119 - lr: 1.0000e-04
# Epoch 7/30
# 10/10 [==============================] - 2s 225ms/step - loss: 1.3788 - accuracy: 0.5449 - val_loss: 1.5062 - val_accuracy: 0.5174 - lr: 1.0000e-04
# Epoch 8/30
# 10/10 [==============================] - 2s 225ms/step - loss: 1.3516 - accuracy: 0.5669 - val_loss: 1.5037 - val_accuracy: 0.5211 - lr: 1.0000e-04
# Epoch 9/30
# 10/10 [==============================] - 2s 230ms/step - loss: 1.3338 - accuracy: 0.5685 - val_loss: 1.5010 - val_accuracy: 0.5303 - lr: 1.0000e-04
# Epoch 10/30
# 10/10 [==============================] - 2s 223ms/step - loss: 1.3086 - accuracy: 0.6031 - val_loss: 1.4980 - val_accuracy: 0.5266 - lr: 1.0000e-04
# Epoch 11/30
# 10/10 [==============================] - 2s 238ms/step - loss: 1.2868 - accuracy: 0.6228 - val_loss: 1.4947 - val_accuracy: 0.5303 - lr: 1.0000e-04
# Epoch 12/30
# 10/10 [==============================] - 2s 222ms/step - loss: 1.2553 - accuracy: 0.6386 - val_loss: 1.4905 - val_accuracy: 0.5358 - lr: 1.0000e-04
# Epoch 13/30
# 10/10 [==============================] - 2s 227ms/step - loss: 1.2265 - accuracy: 0.6598 - val_loss: 1.4863 - val_accuracy: 0.5413 - lr: 1.0000e-04
# Epoch 14/30
# 10/10 [==============================] - 2s 219ms/step - loss: 1.1979 - accuracy: 0.6646 - val_loss: 1.4830 - val_accuracy: 0.5431 - lr: 1.0000e-04
# Epoch 15/30
# 10/10 [==============================] - 2s 224ms/step - loss: 1.1792 - accuracy: 0.6724 - val_loss: 1.4778 - val_accuracy: 0.5541 - lr: 1.0000e-04
# Epoch 16/30
# 10/10 [==============================] - 2s 221ms/step - loss: 1.1495 - accuracy: 0.6929 - val_loss: 1.4724 - val_accuracy: 0.5468 - lr: 1.0000e-04
# Epoch 17/30
# 10/10 [==============================] - 2s 223ms/step - loss: 1.1215 - accuracy: 0.7126 - val_loss: 1.4676 - val_accuracy: 0.5651 - lr: 1.0000e-04
# Epoch 18/30
# 10/10 [==============================] - 2s 235ms/step - loss: 1.0833 - accuracy: 0.7283 - val_loss: 1.4616 - val_accuracy: 0.5523 - lr: 1.0000e-04
# Epoch 19/30
# 10/10 [==============================] - 2s 224ms/step - loss: 1.0469 - accuracy: 0.7378 - val_loss: 1.4551 - val_accuracy: 0.5596 - lr: 1.0000e-04
# Epoch 20/30
# 10/10 [==============================] - 2s 223ms/step - loss: 1.0393 - accuracy: 0.7496 - val_loss: 1.4480 - val_accuracy: 0.5615 - lr: 1.0000e-04
# Epoch 21/30
# 10/10 [==============================] - 2s 219ms/step - loss: 1.0062 - accuracy: 0.7669 - val_loss: 1.4406 - val_accuracy: 0.5651 - lr: 1.0000e-04
# Epoch 22/30
# 10/10 [==============================] - 2s 223ms/step - loss: 0.9684 - accuracy: 0.7906 - val_loss: 1.4367 - val_accuracy: 0.5505 - lr: 1.0000e-04
# Epoch 23/30
# 10/10 [==============================] - 2s 219ms/step - loss: 0.9474 - accuracy: 0.7992 - val_loss: 1.4264 - val_accuracy: 0.5615 - lr: 1.0000e-04
# Epoch 24/30
# 10/10 [==============================] - 2s 224ms/step - loss: 0.9234 - accuracy: 0.8047 - val_loss: 1.4224 - val_accuracy: 0.5780 - lr: 1.0000e-04
# Epoch 25/30
# 10/10 [==============================] - 2s 235ms/step - loss: 0.8875 - accuracy: 0.8205 - val_loss: 1.4104 - val_accuracy: 0.5725 - lr: 1.0000e-04
# Epoch 26/30
# 10/10 [==============================] - 2s 224ms/step - loss: 0.8615 - accuracy: 0.8386 - val_loss: 1.4058 - val_accuracy: 0.5743 - lr: 1.0000e-04
# Epoch 27/30
# 10/10 [==============================] - 2s 225ms/step - loss: 0.8401 - accuracy: 0.8528 - val_loss: 1.3929 - val_accuracy: 0.5963 - lr: 1.0000e-04
# Epoch 28/30
# 10/10 [==============================] - 2s 223ms/step - loss: 0.8142 - accuracy: 0.8472 - val_loss: 1.3880 - val_accuracy: 0.5651 - lr: 1.0000e-04
# Epoch 29/30
# 10/10 [==============================] - 2s 222ms/step - loss: 0.7946 - accuracy: 0.8677 - val_loss: 1.3770 - val_accuracy: 0.5835 - lr: 1.0000e-04
# Epoch 30/30
# 10/10 [==============================] - 2s 222ms/step - loss: 0.7700 - accuracy: 0.8669 - val_loss: 1.3679 - val_accuracy: 0.5908 - lr: 1.0000e-04

# %%
plt.title('Loss')
plt.plot(model.history.history['loss'], label='train')
plt.plot(model.history.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
plt.title('Accuracy')
plt.plot(model.history.history['accuracy'], label='train')
plt.plot(model.history.history['val_accuracy'], label='test')
plt.legend()
plt.show();

# %%
plt.figure(figsize=[8,5])
plt.plot(model.history.history['accuracy'], 'orange')
plt.plot(model.history.history['val_accuracy'], 'blue')
plt.legend(['Validation Training Acc'])
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Validation Accuracy', fontsize=16)
plt.title('Validation Accuracy Curves', fontsize=16)

plt.show()

# %% [markdown]
# ### Evaluation

# %%
test_sequences_matrix = pad_sequences(X_test, maxlen=max_len)

# %%
accuracy = model.evaluate(test_sequences_matrix, Y_test_one_hot, verbose=2, max_queue_size=10)
# Out:
# 18/18 - 0s - loss: 1.3679 - accuracy: 0.5908 - 417ms/epoch - 23ms/step

# %% [markdown]
# #### Loss & Accuracy

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accuracy[0],accuracy[1]))
# Out:
# Test set
#   Loss: 1.368
#   Accuracy: 0.591

# %% [markdown]
# #### Accuracy on Data Train

# %%
_, accuracy = model.evaluate(X_train, Y_train_one_hot, verbose=True)
print(f'Accuracy: {accuracy*100:.2f}')
# Out:
# 40/40 [==============================] - 1s 24ms/step - loss: 1.1984 - accuracy: 0.8913
# Accuracy: 89.13

# %% [markdown]
# #### Accuracy on Data Test

# %%
_, accuracy = model.evaluate(X_test, Y_test_one_hot, verbose=True)
print(f'Accuracy: {accuracy*100:.2f}')
# Out:
# 18/18 [==============================] - 1s 30ms/step - loss: 1.3679 - accuracy: 0.5908
# Accuracy: 59.08

# %% [markdown]
# #### Result

# %% [markdown]
# Setelah melakukan beberapa kali percobaan, saya temukan kombinasi untuk hasil akurasi terbaik pada data test dengan 59% akurasi, yaitu:
#
# - LSTM 144 Node
# - Activation relu pada layer
# - Penambahan regularisasi L1
# - Dropout 0.2
# - Adam Optimizer dengan learning rate 0.0001
# - epochs 30, batch_size 138

# %% [markdown]
# #### Summary

# %% [markdown]
# Loss dan Akurasi pada Data Pelatihan:
#
# - Loss pada data pelatihan adalah sekitar 0.7700, yang mencerminkan seberapa baik model dapat menyesuaikan diri dengan data pelatihan. Akurasi pada data pelatihan adalah sekitar 89.13%, menunjukkan bahwa model memiliki tingkat keakuratan yang tinggi pada data pelatihan.
#
#
# Loss dan Akurasi pada Data Validasi:
#
# - Loss pada data validasi adalah sekitar 1.368. Nilai loss yang lebih tinggi di data validasi dibandingkan dengan data pelatihan menunjukkan kemungkinan adanya overfitting. Model mungkin terlalu rumit dan tidak dapat menggeneralisasi dengan baik ke data yang tidak terlihat selama pelatihan. Akurasi pada data validasi adalah sekitar 59.08%, yang lebih rendah dibandingkan dengan akurasi pada data pelatihan.
#
#
# Model mengalami masalah overfitting, terutama karena perbedaan yang signifikan antara akurasi pada data pelatihan dan data validasi.
#
# Hasil pelatihan dari data yang di stemming lebih baik dari data yang tidak melalui proses stemming (tidak ditampilkan di sini untuk pelatihan dari data yang tidak distemming)

# %% [markdown]
# ### Confusion Matrix & Classification Report

# %%
Y_prediction = model.predict(test_sequences_matrix)
# Out:
# 18/18 [==============================] - 1s 19ms/step

# %%
Y_test_array = np.argmax(Y_test_one_hot, axis=1)
Y_prediction_array = np.argmax(Y_prediction, axis=1)

confusion_matrix_result = confusion_matrix(Y_test_array, Y_prediction_array)
confusion_matrix_result
# Out:
# array([[114,  31,  34],
#        [ 35,  92,  50],
#        [ 46,  27, 116]])

# %%
classification_report_result = classification_report(Y_test_array, Y_prediction_array)

print("Confusion Matrix:")
print(confusion_matrix_result)
print("\nClassification Report:")
print(classification_report_result)

#Heatmap
sns.heatmap(confusion_matrix_result, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Negatif', 'Netral', 'Positif'],
            yticklabels=['Negatif', 'Netral', 'Positif'])
plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:
# [[114  31  34]
#  [ 35  92  50]
#  [ 46  27 116]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61       179
#            1       0.61      0.52      0.56       177
#            2       0.58      0.61      0.60       189
#
#     accuracy                           0.59       545
#    macro avg       0.59      0.59      0.59       545
# weighted avg       0.59      0.59      0.59       545

# %% [markdown]
# #### Hasil Interpretasi Confussion Matrix

# %% [markdown]
# - Model cenderung melakukan kesalahan pada kelas "0" (negatif) dan "2" (positif).
# - Model cukup baik dalam memprediksi kelas "1" (netral).
